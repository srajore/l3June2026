# %%
from langchain_ollama import ChatOllama

# %%
llm = ChatOllama(model="gpt-oss:120b-cloud")

# %%
response = llm.invoke("what is the current weather in Pune City?")

# %%
print(response.content)
# Out:
# I’m not able to pull live data, so I can’t give you the exact temperature, humidity, or forecast for Pune right this moment.
#
# **Quick ways to check the current weather in Pune:**
#
# | Method | How to use it | Typical update frequency |
# |--------|---------------|--------------------------|
# | **Weather websites** | Go to sites like [Weather.com](https://weather.com), [AccuWeather](https://www.accuweather.com), or the Indian Meteorological Department’s portal. Enter “Pune, Maharashtra” in the search box. | Every 5–15 minutes |
# | **Mobile apps** | Install the Weather, AccuWeather, or the Google Weather app on your phone. Enable location services for automatic updates. | Real‑time (push notifications) |
# | **Voice assistants** | Ask Siri, Google Assistant, or Alexa “What’s the weather in Pune right now?” | Instant |
# | **Search engines** | Type “Pune weather” into Google or Bing – a weather card appears at the top of the results page. | Updated automatically |
# ...
