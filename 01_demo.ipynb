# %%
from langchain_ollama import ChatOllama

# %%
llm = ChatOllama(model="gpt-oss:120b-cloud")

# %%
response = llm.invoke("what is the current weather in Pune City?")

# %%
print(response.content)
# Out:
# I’m not able to look up live data, so I can’t give you the exact temperature, humidity, or chance of rain right this moment in Pune. The quickest way to get the current weather is to check a real‑time source such as:
#
# | Platform | How to use it |
# |----------|---------------|
# | **Google Search** | Type “Pune weather” and the search results will show a temperature, short‑term forecast, and a precipitation chance. |
# | **Weather Websites** | • [Weather.com – Pune](https://weather.com/weather/today/l/Pune+India)  <br>• [AccuWeather – Pune](https://www.accuweather.com/en/in/pune/204108/weather-forecast/204108)  <br>• [IMD (India Meteorological Department)](https://mausam.imd.gov.in/) |
# | **Mobile Apps** | • The Weather Channel, • AccuWeather, • Google Weather (built into Android), • Apple Weather (iOS) |
# | **Voice Assistants** | Ask Siri, Google Assistant, or Alexa “What’s the weather in Pune?” |
# | **APIs (if you’re a developer)** | • OpenWeatherMap – `api.openweathermap.org/data/2.5/weather?q=Pune&appid=YOUR_KEY`  <br>• WeatherAPI.com – `api.weatherapi.com/v1/current.json?key=YOUR_KEY&q=Pune` |
#
# ---
#
# ### Quick “What to Expect” in Mid‑June (Typical)
#
# | Parameter | Typical Range |
# |-----------|---------------|
# | **Temperature** | 28 °C – 35 °C (day) / 22 °C – 27 °C (night) |
# | **Humidity** | 70 % – 90 % (quite high) |
# | **Rainfall** | Monsoon season is in full swing; daily chances of a shower or thunderstorm are common (often 2–5 mm + per day). |
# | **Wind** | Light to moderate, usually from the southwest. |
#
# If you need a precise, up‑to‑the‑minute reading (e.g., “22 °C, 78 % humidity, light rain”), just open one of the links above or ask your phone’s voice assistant. That will give you the most reliable, location‑specific data.
